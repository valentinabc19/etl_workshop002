# %%
import pandas as pd
import os
from rapidfuzz import process as rprocess, fuzz
from tqdm import tqdm

# %%
os.chdir("..")
print(os.getcwd())
# Out:
# c:\Users\valen\Desktop\etl_workshop002

# %%
spotify_df = pd.read_csv("data/clean/spotify_artists.csv")
grammy_df = pd.read_csv("data/clean/artist_grammy_nomination.csv")
lastfm_df = pd.read_csv("data/clean/lastfm_artists.csv")

# %%
tqdm.pandas()

df_spotify = spotify_df.copy()
df_grammy = grammy_df.copy()
df_lastfm = lastfm_df.copy()

def normalize_artist_name(name):
    if pd.isna(name):
        return ""
    return str(name).strip().lower()

df_spotify['artist'] = df_spotify['artist'].apply(normalize_artist_name)
df_grammy['artist'] = df_grammy['artist'].apply(normalize_artist_name)
df_lastfm['artist'] = df_lastfm['artist'].apply(normalize_artist_name)

spotify_artists = df_spotify['artist'].unique().tolist()

def get_best_match(name, choices, threshold=90):
    result = rprocess.extractOne(name, choices, scorer=fuzz.token_sort_ratio)
    if result and result[1] >= threshold:
        return result[0]
    return None

df_grammy['matched_artist'] = df_grammy['artist'].progress_apply(lambda x: get_best_match(x, spotify_artists))
df_lastfm['matched_artist'] = df_lastfm['artist'].progress_apply(lambda x: get_best_match(x, spotify_artists))

df_grammy_reduced = df_grammy[['matched_artist', 'nominations', 'year_with_most_nominations',
                               'most_common_category', 'most_common_award_class']]
df_lastfm_reduced = df_lastfm[['matched_artist', 'lastfm_listeners', 'lastfm_playcount',
                               'similar_1', 'similar_2', 'similar_3']]
# Out:
# 100%|██████████| 2792/2792 [00:35<00:00, 79.70it/s]
# 100%|██████████| 17632/17632 [02:08<00:00, 137.24it/s]

# %%
df_merge1 = df_spotify.merge(df_grammy_reduced, how='left', left_on='artist', right_on='matched_artist')

df_final = df_merge1.merge(df_lastfm_reduced, how='left', left_on='artist', right_on='matched_artist', suffixes=('', '_lastfm'))

df_final['nominations'] = df_final['nominations'].fillna(0).astype(int)

df_final.drop(columns=['matched_artist', 'matched_artist_lastfm'], errors='ignore', inplace=True)

# %%
print("Shape final del dataframe:", df_final.shape)
df_final.head()
# Out:
# Shape final del dataframe: (17677, 20)
#                               artist  total_tracks  spotify_popularity  \
# 0                             !nvite             2                23.0
# 1                              #kids             1                34.0
# 2                             $affie             2                41.0
# 3                                &me             1                50.0
# 4  'falsettos' 2016 broadway company             1                30.0
#
#   danceability  energy speechiness instrumentalness  pct_explicit_tracks  \
# 0         High     Low         Low            Vocal                  0.0
# 1       Medium  Medium         Low     Instrumental                  0.0
# 2         High     Low         Low     Instrumental                  0.0
# 3         High  Medium         Low     Instrumental                  0.0
# 4          Low     Low         Low            Vocal                  0.0
#
#    duration_min  feature_pct spotify_track_genre  nominations  \
# 0         2.285          0.0               study            0
# 1         1.730        100.0            children            0
# 2         2.195         50.0               study            0
# 3         6.420        100.0          deep-house            0
# 4         5.140          0.0          show-tunes            0
#
#    year_with_most_nominations most_common_category most_common_award_class  \
# 0                         NaN                  NaN                     NaN
# 1                         NaN                  NaN                     NaN
# 2                         NaN                  NaN                     NaN
# 3                         NaN                  NaN                     NaN
# 4                         NaN                  NaN                     NaN
#
#    lastfm_listeners  lastfm_playcount            similar_1  \
# 0            8030.0           19556.0      Bayleaf Manilla
# 1             815.0            4431.0  Lullabies In Nature
# 2           12512.0           32051.0             Ricki Wu
# 3          138173.0         1164546.0                Rampa
# 4           21687.0          487458.0    Anthony Rosenthal
#
#                  similar_2        similar_3
# 0                   Smiloh           Tentoe
# 1  Modern Children's Songs     Zouzounia TV
# 2           Lobby Lingu!n!           Exxecs
# 3               Adriatique        Adam Port
# 4       Stephanie J. Block  Christian Borle

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17677 entries, 0 to 17676
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   artist                      17677 non-null  object
#  1   total_tracks                17677 non-null  int64
#  2   spotify_popularity          17677 non-null  float64
#  3   danceability                17677 non-null  object
#  4   energy                      17677 non-null  object
#  5   speechiness                 17677 non-null  object
#  6   instrumentalness            17677 non-null  object
#  7   pct_explicit_tracks         17677 non-null  float64
#  8   duration_min                17677 non-null  float64
#  9   feature_pct                 17677 non-null  float64
#  10  spotify_track_genre         17677 non-null  object
#  11  nominations                 17677 non-null  int64
#  12  year_with_most_nominations  657 non-null    float64
#  13  most_common_category        657 non-null    object
#  14  most_common_award_class     657 non-null    object
#  15  lastfm_listeners            17661 non-null  float64
#  16  lastfm_playcount            17661 non-null  float64
#  17  similar_1                   17226 non-null  object
#  18  similar_2                   17222 non-null  object
#  19  similar_3                   17222 non-null  object
# dtypes: float64(7), int64(2), object(11)
# memory usage: 2.7+ MB

# %%
df_final["artist"].unique()
# Out:
# array(['!nvite', '#kids', '$affie', ..., '黃小琥', '黃敏華', '龍藏ryuzo'],
#       shape=(17638,), dtype=object)

# %%
print(f"Number of duplicates: {df_final.duplicated().sum()}")
# Out:
# Number of duplicates: 18

# %%
df_final = df_final.drop_duplicates()

# %%
print(f"Number of duplicates: {df_final.duplicated(subset='artist').sum()}")
# Out:
# Number of duplicates: 21

# %%
duplicates = df_final[df_final.duplicated(subset='artist', keep=False)]
duplicates.head()
# Out:
#                        artist  total_tracks  spotify_popularity danceability  \
# 590           ali farka touré            12               11.25       Medium
# 591           ali farka touré            12               11.25       Medium
# 1421   baby sleep white noise             1               36.00          Low
# 1422   baby sleep white noise             1               36.00          Low
# 1716  berliner philharmoniker             4                0.25          Low
#
#      energy speechiness instrumentalness  pct_explicit_tracks  duration_min  \
# 590     Low         Low            Vocal                  0.0      5.534167
# 591     Low         Low            Vocal                  0.0      5.534167
# 1421    Low         Low     Instrumental                  0.0      1.310000
# 1422    Low         Low     Instrumental                  0.0      1.310000
# 1716    Low         Low     Instrumental                  0.0      3.330000
#
#       feature_pct spotify_track_genre  nominations  \
# 590     66.666667            afrobeat            1
# 591     66.666667            afrobeat            2
# 1421     0.000000               sleep            0
# 1422     0.000000               sleep            0
# 1716   100.000000              german            2
#
#       year_with_most_nominations                most_common_category  \
# 590                       1994.0              Best World Music Album
# 591                       2005.0  Best Traditional World Music Album
# 1421                         NaN                                 NaN
# 1422                         NaN                                 NaN
# 1716                      1999.0    Best Classical Vocal Performance
#
#      most_common_award_class  lastfm_listeners  lastfm_playcount  \
# 590                    album          266779.0         3969159.0
# 591                    album          266779.0         3969159.0
# 1421                     NaN             524.0           78942.0
# 1422                     NaN           30111.0         9552210.0
# 1716                   track          155858.0         2002117.0
#
#                               similar_1                      similar_2  \
# 590   Ali Farka Touré & Toumani Diabaté  Ali Farka Touré and Ry Cooder
# 591   Ali Farka Touré & Toumani Diabaté  Ali Farka Touré and Ry Cooder
# 1421              WHITE NOISE FOR SLEEP               Baby Sleep Music
# 1422                      Erik Eriksson         White Noise For Babies
# 1716              Wiener Philharmoniker     Chicago Symphony Orchestra
#
#               similar_3
# 590   Vieux Farka Touré
# 591   Vieux Farka Touré
# 1421   Pink Noise Sleep
# 1422         littleONES
# 1716   Sir Simon Rattle

# %%
df_final = df_final.sort_values('nominations', ascending=False)
df_final = df_final.drop_duplicates(subset='artist', keep='first')

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17638 entries, 2778 to 5
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   artist                      17638 non-null  object
#  1   total_tracks                17638 non-null  int64
#  2   spotify_popularity          17638 non-null  float64
#  3   danceability                17638 non-null  object
#  4   energy                      17638 non-null  object
#  5   speechiness                 17638 non-null  object
#  6   instrumentalness            17638 non-null  object
#  7   pct_explicit_tracks         17638 non-null  float64
#  8   duration_min                17638 non-null  float64
#  9   feature_pct                 17638 non-null  float64
#  10  spotify_track_genre         17638 non-null  object
#  11  nominations                 17638 non-null  int64
#  12  year_with_most_nominations  646 non-null    float64
#  13  most_common_category        646 non-null    object
#  14  most_common_award_class     646 non-null    object
#  15  lastfm_listeners            17622 non-null  float64
#  16  lastfm_playcount            17622 non-null  float64
#  17  similar_1                   17190 non-null  object
#  18  similar_2                   17186 non-null  object
#  19  similar_3                   17186 non-null  object
# dtypes: float64(7), int64(2), object(11)
# memory usage: 2.8+ MB

# %%
both_null = df_final.loc[df_final["lastfm_listeners"].isna() & df_final["lastfm_playcount"].isna()]
both_null
# Out:
#                         artist  total_tracks  spotify_popularity danceability  \
# 2911          chrystian & ralf             5           46.800000       Medium
# 2966            clarence white             4           23.000000       Medium
# 2985               clay walker             2            0.000000       Medium
# 4189                 dombresky             4           43.500000       Medium
# 9554          maikel delacalle             2            0.000000         High
# 9956                  maunalua             2           24.000000       Medium
# 9991                     maxel             1           30.000000         High
# 9992             maxence cyrin             5           38.600000          Low
# 9993                 maxi rozh             1           27.000000         High
# 9994              maxida märak             3           39.000000         High
# 9995        maximilian sievert             1           60.000000          Low
# 11986                    phyno             1           51.000000         High
# 12727  reynaldo santiago chino             2           36.500000         High
# 15190      the handsome family             1           56.000000         High
# 15234    the kentucky colonels             5           23.600000       Medium
# 16636   white noise baby sleep            17           48.647059          Low
#
#        energy speechiness instrumentalness  pct_explicit_tracks  duration_min  \
# 2911   Medium         Low            Vocal                  0.0      3.726000
# 2966   Medium         Low     Instrumental                  0.0      1.342500
# 2985   Medium         Low            Vocal                  0.0      2.720000
# 4189     High         Low            Vocal                  0.0      3.402500
# 9554     High         Low            Vocal                  0.0      3.660000
# 9956      Low         Low            Vocal                  0.0      4.915000
# 9991     High         Low            Vocal                  0.0      5.110000
# 9992      Low         Low     Instrumental                  0.0      2.690000
# 9993     High         Low            Vocal                  0.0      2.720000
# 9994   Medium         Low            Vocal                  0.0      2.856667
# 9995      Low         Low     Instrumental                  0.0      3.680000
# 11986  Medium         Low            Vocal                  0.0      3.470000
# 12727    High         Low            Vocal                  0.0      4.320000
# 15190  Medium         Low            Vocal                  0.0      2.770000
# 15234    High         Low            Vocal                  0.0      1.712000
# 16636     Low         Low     Instrumental                  0.0      4.246471
#
#        feature_pct spotify_track_genre  nominations  \
# 2911      0.000000           sertanejo            0
# 2966      0.000000           bluegrass            0
# 2985      0.000000             country            0
# 4189     75.000000          deep-house            0
# 9554     50.000000              latino            0
# 9956      0.000000              guitar            0
# 9991      0.000000               disco            0
# 9992      0.000000             ambient            0
# 9993      0.000000              groove            0
# 9994     33.333333             swedish            0
# 9995      0.000000               sleep            0
# 11986   100.000000           dancehall            0
# 12727    50.000000               salsa            0
# 15190     0.000000             country            0
# 15234     0.000000           bluegrass            0
# 16636    41.176471               sleep            0
#
#        year_with_most_nominations most_common_category  \
# 2911                          NaN                  NaN
# 2966                          NaN                  NaN
# 2985                          NaN                  NaN
# 4189                          NaN                  NaN
# 9554                          NaN                  NaN
# 9956                          NaN                  NaN
# 9991                          NaN                  NaN
# 9992                          NaN                  NaN
# 9993                          NaN                  NaN
# 9994                          NaN                  NaN
# 9995                          NaN                  NaN
# 11986                         NaN                  NaN
# 12727                         NaN                  NaN
# 15190                         NaN                  NaN
# 15234                         NaN                  NaN
# 16636                         NaN                  NaN
#
#       most_common_award_class  lastfm_listeners  lastfm_playcount similar_1  \
# 2911                      NaN               NaN               NaN       NaN
# 2966                      NaN               NaN               NaN       NaN
# 2985                      NaN               NaN               NaN       NaN
# 4189                      NaN               NaN               NaN       NaN
# 9554                      NaN               NaN               NaN       NaN
# 9956                      NaN               NaN               NaN       NaN
# 9991                      NaN               NaN               NaN       NaN
# 9992                      NaN               NaN               NaN       NaN
# 9993                      NaN               NaN               NaN       NaN
# 9994                      NaN               NaN               NaN       NaN
# 9995                      NaN               NaN               NaN       NaN
# 11986                     NaN               NaN               NaN       NaN
# 12727                     NaN               NaN               NaN       NaN
# 15190                     NaN               NaN               NaN       NaN
# 15234                     NaN               NaN               NaN       NaN
# 16636                     NaN               NaN               NaN       NaN
#
#       similar_2 similar_3
# 2911        NaN       NaN
# 2966        NaN       NaN
# 2985        NaN       NaN
# 4189        NaN       NaN
# 9554        NaN       NaN
# 9956        NaN       NaN
# 9991        NaN       NaN
# 9992        NaN       NaN
# 9993        NaN       NaN
# 9994        NaN       NaN
# 9995        NaN       NaN
# 11986       NaN       NaN
# 12727       NaN       NaN
# 15190       NaN       NaN
# 15234       NaN       NaN
# 16636       NaN       NaN

# %%
df_final = df_final[~(df_final["lastfm_listeners"].isna() & df_final["lastfm_playcount"].isna())]

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17622 entries, 2778 to 5
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   artist                      17622 non-null  object
#  1   total_tracks                17622 non-null  int64
#  2   spotify_popularity          17622 non-null  float64
#  3   danceability                17622 non-null  object
#  4   energy                      17622 non-null  object
#  5   speechiness                 17622 non-null  object
#  6   instrumentalness            17622 non-null  object
#  7   pct_explicit_tracks         17622 non-null  float64
#  8   duration_min                17622 non-null  float64
#  9   feature_pct                 17622 non-null  float64
#  10  spotify_track_genre         17622 non-null  object
#  11  nominations                 17622 non-null  int64
#  12  year_with_most_nominations  646 non-null    float64
#  13  most_common_category        646 non-null    object
#  14  most_common_award_class     646 non-null    object
#  15  lastfm_listeners            17622 non-null  float64
#  16  lastfm_playcount            17622 non-null  float64
#  17  similar_1                   17190 non-null  object
#  18  similar_2                   17186 non-null  object
#  19  similar_3                   17186 non-null  object
# dtypes: float64(7), int64(2), object(11)
# memory usage: 2.8+ MB

# %%
df_final.to_csv("data/clean/merged_data.csv", index=False)
